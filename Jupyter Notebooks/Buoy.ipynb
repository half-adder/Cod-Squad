# %%
import pandas as pd

# %%
m01 = pd.read_csv('../data/buoy/m01_buoy.csv')
n01 = pd.read_csv('../data/buoy/n01_buoy.csv')

# %%
m01 = m01.drop('Unnamed: 0', axis=1)
n01 = n01.drop('Unnamed: 0', axis=1)
m01.to_csv('../data/buoy/')
# Out:
#           year  month  date  hour  minute  visibility_m  wave_height_m  \
# 0       2015.0    1.0   1.0   0.0     0.0       2956.72           1.70
# 1       2015.0    1.0   1.0   0.0    10.0       2956.72            NaN
# 2       2015.0    1.0   1.0   0.0    20.0       2956.72            NaN
# 3       2015.0    1.0   1.0   0.0    30.0       2956.72           1.75
# 4       2015.0    1.0   1.0   0.0    40.0       2956.72            NaN
# 5       2015.0    1.0   1.0   0.0    50.0       2956.72            NaN
# 6       2015.0    1.0   1.0   1.0     0.0       2956.72           1.43
# 7       2015.0    1.0   1.0   1.0    10.0       2956.72            NaN
# 8       2015.0    1.0   1.0   1.0    20.0       2956.72            NaN
# 9       2015.0    1.0   1.0   1.0    30.0       2956.72           1.56
# 10      2015.0    1.0   1.0   1.0    40.0       2956.72            NaN
# 11      2015.0    1.0   1.0   1.0    50.0       2956.72            NaN
# ...
